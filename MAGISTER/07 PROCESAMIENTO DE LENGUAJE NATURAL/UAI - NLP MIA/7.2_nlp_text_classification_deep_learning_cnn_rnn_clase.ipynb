# %% [markdown]
# #Chile - Universidad Adolfo Ibáñez (UAI)
# ##Curso NLP
# ### Text Classification - Sentiment Analysis (Inglés) - CNN & RNN

# %% [markdown]
# # Carga & Exploración de Datos

# %%
#Importar Librerías
import pandas as pd
import numpy as np
import spacy

# %%
#Importar Archivos
df_train = pd.read_csv('/content/sentiment_analysis_train.csv', encoding='latin-1')
df_test = pd.read_csv('/content/sentiment_analysis_test.csv', encoding='latin-1')

# %%
#Verificar Columnas
print("Columnas Train:", df_train.columns)
print("Columnas Test:", df_test.columns)
# Out:
# Columnas Train: Index(['UserName', 'ScreenName', 'Location', 'TweetAt', 'OriginalTweet',
#        'Sentiment'],
#       dtype='object')
# Columnas Test: Index(['UserName', 'ScreenName', 'Location', 'TweetAt', 'OriginalTweet',
#        'Sentiment'],
#       dtype='object')

# %%
#Verificar Distribución Label (Train)
print("Label Distribution (Train)\n", df_train['Sentiment'].value_counts(normalize=True))
# Out:
# Label Distribution (Train)
#  Sentiment
# Positive    0.4330
# Negative    0.3722
# Neutral     0.1948
# Name: proportion, dtype: float64

# %%
#Verificar Distribución Label (Test)
print("Label Distribution (Test)\n", df_test['Sentiment'].value_counts(normalize=True))
# Out:
# Label Distribution (Test)
#  Sentiment
# Negative    0.449
# Positive    0.404
# Neutral     0.147
# Name: proportion, dtype: float64

# %% [markdown]
# # Embedding Matrix

# %%
#Importar Librerías
import tensorflow as tf
from tensorflow import keras
from keras.layers import TextVectorization

# %%
#Descargar spaCy pipeline
# !python -m spacy download en_core_web_lg -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 3.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
#Cargar Pipeline
nlp = spacy.load("en_core_web_lg")

# %%
#Crear Vocabulario
vectorizer = TextVectorization()
vectorizer.adapt(df_train['OriginalTweet'])
vocab = vectorizer.get_vocabulary()

# %%
#Generar Embedding Matrix
num_tokens = len(vocab)
embedding_dim = len(nlp('the').vector)
embedding_matrix = np.zeros((num_tokens, embedding_dim))
for i, word in enumerate(vocab):
    embedding_matrix[i] = nlp(word.lower()).vector

print("Dimensionalidad Matriz Embeddings:", embedding_matrix.shape)
# Out:
# Dimensionalidad Matriz Embeddings: (19975, 300)

# %% [markdown]
# # Pre-Procesamiento

# %%
#Importar Librerías
#from keras.preprocessing.text import Tokenizer
#import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from sklearn.preprocessing import LabelBinarizer

# %%
#Crear & Entrenar Tokenizador (Keras)
vocab_size = num_tokens
oov_tok = '<OOV>'
tokenizer = Tokenizer(num_words=vocab_size,
                      oov_token=oov_tok)
tokenizer.fit_on_texts(df_train['OriginalTweet'])

# %%
#Crear Sequencias de Texto (Train)
trunc_type='post'
max_length = 250
X_train_seq = tokenizer.texts_to_sequences(df_train['OriginalTweet'])
X_train_seq_padded = pad_sequences(X_train_seq, maxlen=max_length, truncating=trunc_type)
print("X Train Sequences:", X_train_seq_padded.shape)
# Out:
# X Train Sequences: (5000, 250)

# %%
#Crear Sequencias de Texto (Test)
X_test_seq = tokenizer.texts_to_sequences(df_test['OriginalTweet'])
X_test_seq_padded = pad_sequences(X_test_seq, maxlen=max_length, truncating=trunc_type)
print("X Test Sequences:", X_test_seq_padded.shape)
# Out:
# X Test Sequences: (1000, 250)

# %%
#Listado Ordeneado de Clases
classes = ['Negative',
           'Neutral',
           'Positive']

# %%
#Crear & Entrenar Objeto LabelBinarizer
lb = LabelBinarizer()
lb.fit(df_train['Sentiment'])
# Out:
# LabelBinarizer()

# %%
#Creación Vector Labels
y_train = lb.transform(df_train['Sentiment'])
y_test = lb.transform(df_test['Sentiment'])

# %% [markdown]
# # CNN (3 Layers)

# %%
#Importar Librerías
import tensorflow as tf
from tensorflow import keras
#from keras.models import Sequential
from keras import Sequential
from keras.layers import Dense, Embedding,Conv1D,GlobalMaxPool1D
from keras import initializers
from keras.callbacks import EarlyStopping
from sklearn.metrics import f1_score

# %%
#Creación & Configuración Objeto Sequential

#Inicializar Modelo
model_cnn_3l = Sequential()

#Capa Entrada - Embedding Layer
model_cnn_3l.add(Embedding(input_dim=vocab_size,
                           output_dim=embedding_dim,
                           embeddings_initializer=initializers.Constant(embedding_matrix),
                           trainable=False))

#Convolutional Layer
model_cnn_3l.add(Conv1D(32, 5, activation='relu'))

#Max Pooling Layer
model_cnn_3l.add(GlobalMaxPool1D())

#Fully Connected Layer
model_cnn_3l.add(Dense(32, activation='relu'))

#Capa Salida
model_cnn_3l.add(Dense(3, activation='softmax'))

#Compilación
model_cnn_3l.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_cnn_3l.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ ?                      │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#Configurar EarlyStopping
early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=3)

# %%
#Entrenar CNN
history_cnn_3l = model_cnn_3l.fit(X_train_seq_padded, y_train,
                                  batch_size=5,
                                  epochs=10,
                                  validation_split=0.2,
                                  callbacks=[early_stop])
# Out:
# Epoch 1/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.4142 - loss: 1.0531 - val_accuracy: 0.4370 - val_loss: 1.0268
# Epoch 2/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5764 - loss: 0.9138 - val_accuracy: 0.5380 - val_loss: 0.9173
# Epoch 3/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7076 - loss: 0.7095 - val_accuracy: 0.5450 - val_loss: 0.9861
# Epoch 4/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8612 - loss: 0.4023 - val_accuracy: 0.5350 - val_loss: 1.1310
# Epoch 5/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9411 - loss: 0.1928 - val_accuracy: 0.5090 - val_loss: 1.6735
# Epoch 6/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9804 - loss: 0.0900 - val_accuracy: 0.5390 - val_loss: 1.6420

# %%
#Gráfico Accuracy & Loss (Training & Validation)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

def plot_accuracy_loss(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training Accuracy')
    plt.plot(x, val_acc, 'r', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Number of Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training Loss')
    plt.plot(x, val_loss, 'r', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Number of Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
#Revisar Accuracy & Loss
plot_accuracy_loss(history_cnn_3l)

# %%
#Umbral de Predicción
threshold = 0.5

# %%
#Evaluar CNN
y_pred_cnn_3l = model_cnn_3l.predict(X_test_seq_padded) > threshold
print('F1 Score (Weighted)', round(f1_score(y_test, y_pred_cnn_3l, average='weighted'),3))
print('F1 Score (por Clase)', f1_score(y_test, y_pred_cnn_3l, average=None))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
# F1 Score (Weighted) 0.534
# F1 Score (por Clase) [0.55813953 0.375      0.56548348]

# %% [markdown]
# # RNN (4 Layers)

# %%
#Importar Librerías
from keras.layers import Bidirectional, LSTM

# %%
#Creación & Configuración Objeto Sequential

#Inicializar Modelo
model_rnn_3l = Sequential()

#Capa Entrada - Embedding Layer
model_rnn_3l.add(Embedding(input_dim=vocab_size,
                           output_dim=embedding_dim,
                           embeddings_initializer=initializers.Constant(embedding_matrix),
                           trainable=False))

#Bidirectional LSTM Layer
model_rnn_3l.add(Bidirectional(LSTM(units=10)))

#Fully Connected Layer
model_rnn_3l.add(Dense(10, activation='relu'))

#Capa Salida
model_rnn_3l.add(Dense(3, activation='softmax'))

#Compilación
model_rnn_3l.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_rnn_3l.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#Entrenar RNN
history_rnn_3l = model_rnn_3l.fit(X_train_seq_padded, y_train,
                                  batch_size=5,
                                  epochs=10,
                                  validation_split=0.2,
                                  callbacks=[early_stop])
# Out:
# Epoch 1/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - accuracy: 0.4183 - loss: 1.0569 - val_accuracy: 0.4610 - val_loss: 0.9876
# Epoch 2/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.4557 - loss: 1.0161 - val_accuracy: 0.4750 - val_loss: 0.9676
# Epoch 3/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.5072 - loss: 0.9532 - val_accuracy: 0.5030 - val_loss: 0.9583
# Epoch 4/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.5703 - loss: 0.8985 - val_accuracy: 0.4980 - val_loss: 0.9677
# Epoch 5/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6241 - loss: 0.8344 - val_accuracy: 0.5200 - val_loss: 0.9555
# Epoch 6/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.6759 - loss: 0.7515 - val_accuracy: 0.5240 - val_loss: 1.0081
# Epoch 7/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.7288 - loss: 0.6777 - val_accuracy: 0.5370 - val_loss: 1.0405
# Epoch 8/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.7576 - loss: 0.6090 - val_accuracy: 0.5210 - val_loss: 1.0779
# Epoch 9/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.8010 - loss: 0.5480 - val_accuracy: 0.5060 - val_loss: 1.1479
# Epoch 10/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.8206 - loss: 0.4885 - val_accuracy: 0.5120 - val_loss: 1.1929

# %%
#Revisar Accuracy & Loss
plot_accuracy_loss(history_rnn_3l)

# %%
#Evaluar RNN
y_pred_rnn_3l = model_rnn_3l.predict(X_test_seq_padded) > threshold
print('F1 Score (Weighted)', round(f1_score(y_test, y_pred_rnn_3l, average='weighted'),3))
print('F1 Score (por Clase)', f1_score(y_test, y_pred_rnn_3l, average=None))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# F1 Score (Weighted) 0.52
# F1 Score (por Clase) [0.53285544 0.41958042 0.54193548]
